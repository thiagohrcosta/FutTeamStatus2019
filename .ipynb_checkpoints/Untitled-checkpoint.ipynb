# %%
import pandas as pd
import numpy as np

# %%
myplayers = pd.read_csv("myFutTEAM.csv")
myplayers.head(35)
# Out:
#                Name    Country Position             Club          League  \
# 0      Thiago Silva     Brazil       CB              PSG        League 1
# 1          Di Maria  Argentina       CF              PSG        League 1
# 2        Donnarumma      Italy       GK            Milan         Serie A
# 3         Chiellini      Italy       CB         Juventus         Serie A
# 4           Verrati      Italy       CM              PSG        League 1
# 5    Bernardo Silva   Portugal       CM  Manchester City  Premier League
# 6      Joao Cancelo   Portugal       RB         Juventus         Serie A
# 7       Alex Telles     Brazil       LB            Porto        Liga NOS
# 8   Roberto Firmino     Brazil       CF         Liverpol  Premier League
# 9          Kimpenbe     France       CB              PSG        League 1
# 10        Neymar Jr     Brazil       LW              PSG        League 1
# 11           Cavani    Uruguay       CF              PSG        League 1
# ...

# %%
# Import the CSV from the Squad Battle Games
squadbattlestatus = pd.read_csv("squadbattlesgames.csv")
squadbattlestatus.head()
# Out:
#   Team Name  Overal  Best CPU       Club   League   Tatics  SB Points  \
# 0  Zubumafu      84  Coutinho  Barcelona  La Liga  4-2-2-2      2.121
#
#    Shoots 1st Half  Shoots 2nd Half Best Player  ...  Penalty  Long Pass  \
# 0                8                7       Allan  ...        0          0
#
#    Cross  Goals Taken  CPU Corner  CPU Long Shot  CPU Inner Shot  \
# 0      0            2           0              1               1
#
#     CPU Penalty  CPU Long Pass  CPU Cross
# 0             0              0          0
#
# [1 rows x 25 columns]
